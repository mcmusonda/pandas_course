# %% [markdown]
# # Chapter 6-1: Selecting DataFrames

# %%
import pandas as pd
# Display numbers in human readable format
pd.options.display.float_format = '{:.2f}'.format

# %%
houses_path = 'data/kc_house_data.csv'

# %%
house_sales = pd.read_csv(houses_path)
house_sales.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.00         3       1.00         1180
# 1  6414100192  20141209T000000  538000.00         3       2.25         2570
# 2  5631500400  20150225T000000  180000.00         2       1.00          770
# 3  2487200875  20141209T000000  604000.00         4       3.00         1960
# 4  1954400510  20150218T000000  510000.00         3       2.00         1680
# 5  7237550310  20140512T000000 1225000.00         4       4.50         5420
# 6  1321400060  20140627T000000  257500.00         3       2.25         1715
# 7  2008000270  20150115T000000  291850.00         3       1.50         1060
# 8  2414600126  20150415T000000  229500.00         3       1.00         1780
# 9  3793500160  20150312T000000  323000.00         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
house_sales.iloc[6]
# Out:
# id                    1321400060
# date             20140627T000000
# price                  257500.00
# bedrooms                       3
# bathrooms                   2.25
# sqft_living                 1715
# sqft_lot                    6819
# floors                      2.00
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1715
# sqft_basement                  0
# yr_built                    1995
# yr_renovated                   0
# zipcode                    98003
# lat                        47.31
# long                     -122.33
# sqft_living15               2238
# sqft_lot15                  6819
# Name: 6, dtype: object

# %%
house_sales.iloc[[3, 6, 9]]
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 3  2487200875  20141209T000000 604000.00         4       3.00         1960
# 6  1321400060  20140627T000000 257500.00         3       2.25         1715
# 9  3793500160  20150312T000000 323000.00         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3      5000    1.00           0     0  ...      7        1050            910
# 6      6819    2.00           0     0  ...      7        1715              0
# 9      6560    2.00           0     0  ...      7        1890              0
#
#    yr_built  yr_renovated  zipcode   lat    long  sqft_living15  sqft_lot15
# 3      1965             0    98136 47.52 -122.39           1360        5000
# 6      1995             0    98003 47.31 -122.33           2238        6819
# 9      2003             0    98038 47.37 -122.03           2390        7570
#
# [3 rows x 21 columns]

# %%
sub_house_sales = house_sales.iloc[[3, 6, 9]]
type(sub_house_sales)
# Out:
# pandas.core.frame.DataFrame

# %%
house_sales.iloc[[3, 6, 9], [3, 4,5,6,7]]
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 3         4       3.00         1960      5000    1.00
# 6         3       2.25         1715      6819    2.00
# 9         3       2.50         1890      6560    2.00

# %% [markdown]
# ## Slicing

# %%
house_sales.iloc[[3, 6, 9], 3:8]
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 3         4       3.00         1960      5000    1.00
# 6         3       2.25         1715      6819    2.00
# 9         3       2.50         1890      6560    2.00

# %%
sample = house_sales.iloc[9999:11000, 3:8]

# %%
sample
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 9999          3       2.25         1680     35127    2.00
# 10000         4       2.50         1910     10300    1.00
# 10001         5       3.25         3160     10587    1.00
# 10002         3       1.50         2020     11358    1.00
# 10003         4       3.75         3210      7054    2.00
# ...         ...        ...          ...       ...     ...
# 10995         3       2.50         2740     18455    2.00
# 10996         3       2.75         2610     11290    1.00
# 10997         3       1.75         1400      7920    1.00
# 10998         3       2.00         2570     28500    1.00
# 10999         4       2.75         2830      7334    2.00
#
# [1001 rows x 5 columns]
