# %% [markdown]
# # Chapter 7-2: Applying other criteria

# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
house_path = 'data/kc_house_data.csv'

# %%
house_sales = pd.read_csv(house_path)
house_sales.head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 221900.0         3        1.0         1180
# 1  6414100192  20141209T000000 538000.0         3        2.2         2570
# 2  5631500400  20150225T000000 180000.0         2        1.0          770
# 3  2487200875  20141209T000000 604000.0         4        3.0         1960
# 4  1954400510  20150218T000000 510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Equality Opposite number Inequality "!="

# %%
house_sales['zipcode'] != 98198
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 21608    True
# 21609    True
# 21610    True
# 21611    True
# 21612    True
# Name: zipcode, Length: 21613, dtype: bool

# %%
not_98198 = house_sales['zipcode'] != 98198

# %%
anything_but_98198 = house_sales[not_98198]
anything_but_98198
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000 221900.0         3        1.0         1180
# 1      6414100192  20141209T000000 538000.0         3        2.2         2570
# 2      5631500400  20150225T000000 180000.0         2        1.0          770
# 3      2487200875  20141209T000000 604000.0         4        3.0         1960
# 4      1954400510  20150218T000000 510000.0         3        2.0         1680
# ...           ...              ...      ...       ...        ...          ...
# 21608   263000018  20140521T000000 360000.0         3        2.5         1530
# 21609  6600060120  20150223T000000 400000.0         4        2.5         2310
# 21610  1523300141  20140623T000000 402101.0         2        0.8         1020
# 21611   291310100  20150116T000000 400000.0         3        2.5         1600
# 21612  1523300157  20141015T000000 325000.0         2        0.8         1020
#
# ...

# %%
len(anything_but_98198)
# Out:
# 21333

# %%
len(house_sales)
# Out:
# 21613

# %% [markdown]
# ## Less than operator

# %%
less_than = house_sales['price'] < 250000
less_than
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: price, Length: 21613, dtype: bool

# %%
# index the dataframe
affordable_homes = house_sales[less_than]
affordable_homes.head()
# Out:
#             id             date    price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000 221900.0         3        1.0         1180
# 2   5631500400  20150225T000000 180000.0         2        1.0          770
# 8   2414600126  20150415T000000 229500.0         3        1.0         1780
# 18    16000397  20141205T000000 189000.0         2        1.0         1200
# 19  7983200060  20150424T000000 230000.0         3        1.0         1250
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0       5650     1.0           0     0  ...      7        1180              0
# 2      10000     1.0           0     0  ...      6         770              0
# 8       7470     1.0           0     0  ...      7        1050            730
# 18      9850     1.0           0     0  ...      7        1200              0
# 19      9774     1.0           0     0  ...      7        1250              0
#
# ...

# %%
affordable_homes.describe()
# Out:
#                 id    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# count       2303.0   2303.0    2303.0     2303.0       2303.0    2303.0
# mean  4504484378.2 205892.2       2.9        1.4       1272.6   10552.2
# std   2844608489.7  35098.2       0.8        0.5        374.0   28926.5
# min      2800031.0  75000.0       0.0        0.0        290.0     772.0
# 25%   1944650152.5 187000.0       2.0        1.0       1000.0    6250.0
# 50%   3832300090.0 215000.0       3.0        1.0       1230.0    7958.0
# 75%   7335400372.5 234000.0       3.0        1.8       1510.0    9774.5
# max   9835801000.0 249950.0       6.0        3.5       2600.0 1164794.0
#
#        floors  waterfront   view  condition  grade  sqft_above  sqft_basement  \
# count  2303.0      2303.0 2303.0     2303.0 2303.0      2303.0         2303.0
# mean      1.1         0.0    0.0        3.4    6.5      1174.1           98.5
# std       0.3         0.0    0.2        0.7    0.7       321.0          232.5
# ...

# %%
ten_plus_bedrooms = house_sales['bedrooms'] >= 10

# %%
# indexing the dataframes
house_sales[ten_plus_bedrooms].head()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000  520000.0        11        3.0
# 13314   627300145  20140814T000000 1148000.0        10        5.2
# 15161  5566100170  20141029T000000  650000.0        10        2.0
# 15870  2402100895  20140625T000000  640000.0        33        1.8
# 19254  8812401450  20141229T000000  660000.0        10        3.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  lat   long  \
# 8757         2400            600      1918          1999    98106 47.6 -122.4
# ...

# %%
house_sales[house_sales['bedrooms'] >= 10]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000  520000.0        11        3.0
# 13314   627300145  20140814T000000 1148000.0        10        5.2
# 15161  5566100170  20141029T000000  650000.0        10        2.0
# 15870  2402100895  20140625T000000  640000.0        33        1.8
# 19254  8812401450  20141229T000000  660000.0        10        3.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  lat   long  \
# 8757         2400            600      1918          1999    98106 47.6 -122.4
# ...
