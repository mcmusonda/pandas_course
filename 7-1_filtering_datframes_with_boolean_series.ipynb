# %% [markdown]
# # Chapter 7-1: Filtering DataFrames with a Boolean Series

# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
house_path = 'data/kc_house_data.csv'

# %%
house_sales = pd.read_csv(house_path)
house_sales.head(10)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3        1.0         1180
# 1  6414100192  20141209T000000  538000.0         3        2.2         2570
# 2  5631500400  20150225T000000  180000.0         2        1.0          770
# 3  2487200875  20141209T000000  604000.0         4        3.0         1960
# 4  1954400510  20150218T000000  510000.0         3        2.0         1680
# 5  7237550310  20140512T000000 1225000.0         4        4.5         5420
# 6  1321400060  20140627T000000  257500.0         3        2.2         1715
# 7  2008000270  20150115T000000  291850.0         3        1.5         1060
# 8  2414600126  20150415T000000  229500.0         3        1.0         1780
# 9  3793500160  20150312T000000  323000.0         3        2.5         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# ## Filter Houses with 3 bedrooms only
# A boolean series is a pandas series where either all the values are true or false

# %%
house_sales['bedrooms']
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
house_sales['bedrooms'] == 3
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 21608     True
# 21609    False
# 21610    False
# 21611     True
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
three_bedrooms = house_sales['bedrooms'] == 3

# %%
house_sales[three_bedrooms]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000 221900.0         3        1.0         1180
# 1      6414100192  20141209T000000 538000.0         3        2.2         2570
# 4      1954400510  20150218T000000 510000.0         3        2.0         1680
# 6      1321400060  20140627T000000 257500.0         3        2.2         1715
# 7      2008000270  20150115T000000 291850.0         3        1.5         1060
# ...           ...              ...      ...       ...        ...          ...
# 21603  7852140040  20140825T000000 507250.0         3        2.5         2270
# 21604  9834201367  20150126T000000 429000.0         3        2.0         1490
# 21607  2997800021  20150219T000000 475000.0         3        2.5         1310
# 21608   263000018  20140521T000000 360000.0         3        2.5         1530
# 21611   291310100  20150116T000000 400000.0         3        2.5         1600
#
# ...

# %%
three_bedrooms_df = house_sales[three_bedrooms]
three_bedrooms_df.describe()
# Out:
#                 id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# count       9824.0    9824.0    9824.0     9824.0       9824.0    9824.0
# mean  4535884163.4  466232.1       3.0        2.0       1805.8   14414.8
# std   2874660413.9  262469.8       0.0        0.6        623.1   35652.5
# min      1200021.0   82000.0       3.0        0.8        490.0     572.0
# 25%   2085200474.0  295487.5       3.0        1.5       1370.0    5000.0
# 50%   3856904795.0  413000.0       3.0        2.0       1680.0    7629.5
# 75%   7287250116.0  560000.0       3.0        2.5       2110.0   10364.0
# max   9900000190.0 3800000.0       3.0        4.5       6400.0  843309.0
#
#        floors  waterfront   view  condition  grade  sqft_above  sqft_basement  \
# count  9824.0      9824.0 9824.0     9824.0 9824.0      9824.0         9824.0
# mean      1.4         0.0    0.2        3.4    7.5      1584.4          221.4
# ...
