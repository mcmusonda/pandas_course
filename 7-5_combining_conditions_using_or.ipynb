# %% [markdown]
# # Chapter 7-5: Combining Conditions Using the || Operator

# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
house_path = 'data/kc_house_data.csv'

# %%
house_sales = pd.read_csv(house_path)
house_sales.head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 221900.0         3        1.0         1180
# 1  6414100192  20141209T000000 538000.0         3        2.2         2570
# 2  5631500400  20150225T000000 180000.0         2        1.0          770
# 3  2487200875  20141209T000000 604000.0         4        3.0         1960
# 4  1954400510  20150218T000000 510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
sqft_living = house_sales['sqft_living'] >= 4000
sqft_lot = house_sales['sqft_lot'] >= 12000
bedrroms = house_sales['bedrooms'] >= 5
waterfront = house_sales['waterfront'] == 1

# %%
fancy_houses = house_sales[sqft_living | sqft_lot | bedrroms | waterfront]
fancy_houses.head(20)
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 5   7237550310  20140512T000000 1225000.0         4        4.5         5420
# 12   114101516  20140528T000000  310000.0         3        1.0         1430
# 14  1175000570  20150312T000000  530000.0         5        2.0         1810
# 16  1875500060  20140731T000000  395000.0         3        2.0         1890
# 21  2524049179  20140826T000000 2000000.0         3        2.8         3050
# 22  7137970340  20140703T000000  285000.0         5        2.5         2270
# 36  9435300030  20140528T000000  550000.0         4        1.0         1660
# 41  7766200013  20140811T000000  775000.0         4        2.2         4220
# 42  7203220400  20140707T000000  861990.0         5        2.8         3595
# 45  8035350320  20140718T000000  488000.0         3        2.5         3160
# 47  4178300310  20140716T000000  785000.0         4        2.5         2290
# ...
